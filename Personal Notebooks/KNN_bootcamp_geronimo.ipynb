# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

ruta_archivo = "df_scaled_cirrosis_normalizado.csv"
df = pd.read_csv(ruta_archivo, sep=',')

# %% [markdown]
# # KNN con la data escalada y normalizada

# %%
# Assuming 'Result' is the target variable and other columns are features
X = df.drop('Stage', axis=1)
y = df['Stage']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Initialize and train the KNN classifier (you might want to tune the number of neighbors)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# Predict on the test set
y_pred = knn.predict(X_test)

# Get the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=knn.classes_, yticklabels=knn.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Get the classification report (includes precision, recall, f1-score)
report = classification_report(y_test, y_pred)

# Print the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.29      1.00      0.44         2
#            1       0.30      0.19      0.23        16
#            2       0.38      0.46      0.42        28
#            3       0.56      0.43      0.49        23
#
#     accuracy                           0.41        69
#    macro avg       0.38      0.52      0.40        69
# weighted avg       0.42      0.41      0.40        69

# %% [markdown]
# # KNN con la data con 2 componentes principales PCA

# %%
ruta_archivo2 = "dataframe_pca_2components.csv"
df2 = pd.read_csv(ruta_archivo2, sep=',')

# %%
# Assuming 'Result' is the target variable and other columns are features
X = df2.drop('Stage', axis=1)
y = df2['Stage']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Initialize and train the KNN classifier (you might want to tune the number of neighbors)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# Predict on the test set
y_pred = knn.predict(X_test)

# Get the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=knn.classes_, yticklabels=knn.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Get the classification report (includes precision, recall, f1-score)
report = classification_report(y_test, y_pred)

# Print the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.14      0.50      0.22         2
#            1       0.17      0.12      0.14        16
#            2       0.38      0.43      0.40        28
#            3       0.67      0.52      0.59        23
#
#     accuracy                           0.39        69
#    macro avg       0.34      0.39      0.34        69
# weighted avg       0.42      0.39      0.40        69

# %% [markdown]
# # KNN con el dataset en limpio

# %%
ruta_archivo3 = "dataframe_final_llimpio_Geronimo_Saldaña.csv"
df3 = pd.read_csv(ruta_archivo3, sep=',')

# %%
# Assuming 'Result' is the target variable and other columns are features
X = df3.drop('Stage', axis=1)
y = df3['Stage']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Initialize and train the KNN classifier (you might want to tune the number of neighbors)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# Predict on the test set
y_pred = knn.predict(X_test)

# Get the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=knn.classes_, yticklabels=knn.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Get the classification report (includes precision, recall, f1-score)
report = classification_report(y_test, y_pred)

# Print the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.29      0.31      0.30        16
#            2       0.42      0.50      0.46        28
#            3       0.53      0.43      0.48        23
#
#     accuracy                           0.42        69
#    macro avg       0.31      0.31      0.31        69
# weighted avg       0.42      0.42      0.42        69
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
